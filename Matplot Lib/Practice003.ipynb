# %%
# histogram
data = [2,2,2,3,5,4,5,6,6,6,6,6,7,8,8]
from matplotlib import pyplot as plt
plt.hist(data)
plt.show()

# %%
import pandas as pd 
import numpy as np
file = pd.read_csv(r"C:\Users\dellj\Desktop\Machine leraning\Pandas\cities_r2.csv")
file.head()
plt.plot(file["population_total"],file["population_male"],color="r")
plt.show()
