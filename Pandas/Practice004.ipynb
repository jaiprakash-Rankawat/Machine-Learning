# %%
list1 = [1,2,3,4,5]
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
import pandas as pd

# %%
data = pd.Series(list1)
print(data)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
data = {"name":["Ram","Shyam"],"age":[32,22]}
df = pd.DataFrame(data)
print(df)
# Out:
#     name  age
# 0    Ram   32
# 1  Shyam   22

# %%
from sklearn.datasets import fetch_openml
boston = fetch_openml(name="boston", version=1, as_frame=True)
df = boston.frame
print(df.head())
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df_numeric = df.select_dtypes(include=['number'])  # Keep only numeric columns
# print(df_numeric.mean())  # Mean of numeric columns
# print(df_numeric.std())   # Standard deviation of numeric columns
# print(df_numeric.min())   # Minimum values of numeric colum
df_numeric.max()
df_numeric.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         TAX     PTRATIO           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043  408.237154   18.455534  356.674032   12.653063   22.532806
# ...

# %%
# reading a csv file 

cities = pd.read_csv("cities_r2.csv")
print(cities.value_counts("state_name"))
cities.head()
# Out:
# state_name
# UTTAR PRADESH                63
# WEST BENGAL                  61
# MAHARASHTRA                  43
# ANDHRA PRADESH               42
# MADHYA PRADESH               32
# TAMIL NADU                   32
# GUJARAT                      29
# RAJASTHAN                    29
# BIHAR                        26
# KARNATAKA                    26
# HARYANA                      20
# PUNJAB                       16
# NCT OF DELHI                 15
# ORISSA                       10
# JHARKHAND                    10
# CHHATTISGARH                  9
# KERALA                        7
# UTTARAKHAND                   6
# ASSAM                         4
# JAMMU & KASHMIR               3
# PUDUCHERRY                    2
# HIMACHAL PRADESH              1
# CHANDIGARH                    1
# ANDAMAN & NICOBAR ISLANDS     1
# MEGHALAYA                     1
# MIZORAM                       1
# NAGALAND                      1
# MANIPUR                       1
# TRIPURA                       1
# ...

# %%
import numpy as np
import pandas as pd 

random_df = pd.DataFrame(np.random.randint(10,36,(4,5)))
random_df.head()
random_df.size
random_df.shape
random_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      int32
#  1   1       4 non-null      int32
#  2   2       4 non-null      int32
#  3   3       4 non-null      int32
#  4   4       4 non-null      int32
# dtypes: int32(5)
# memory usage: 212.0 bytes
