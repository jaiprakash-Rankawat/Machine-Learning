# %%
# accessing row and columns 

# rows
import pandas as pd
df = pd.read_csv("cities_r2.csv")
df.iloc[1]
# Out:
# name_of_city                                 Achalpur
# state_code                                          27
# state_name                                 MAHARASHTRA
# dist_code                                            7
# population_total                                112293
# population_male                                  58256
# population_female                                54037
# 0-6_population_total                             11810
# 0-6_population_male                               6186
# 0-6_population_female                             5624
# literates_total                                  92433
# literates_male                                   49347
# literates_female                                 43086
# sex_ratio                                          928
# child_sex_ratio                                    909
# effective_literacy_rate_total                    91.99
# effective_literacy_rate_male                     94.77
# ...

# %%
# accessing multiple rows 
df.iloc[2:5]
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 2                 6731                   6372  ...             37660
# 3                12063                  10979  ...             54515
# 4                 9355                   9051  ...             45089
#
#    sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 2        982              947                          80.51
# ...

# %%
# accessing columns
df["name_of_city"]
# Out:
# 0            Abohar
# 1          Achalpur
# 2          Adilabad
# 3         Adityapur
# 4             Adoni
#            ...
# 488    Vizianagaram
# 489        Warangal
# 490          Wardha
# 491     Yamunanagar
# 492        Yavatmal
# Name: name_of_city, Length: 493, dtype: object

# %%
# accessing total population in 2nd row
print(df.loc[1,"population_total"])
# Out:
# 112293

# %%
# filtering 
df[df["state_code"]==8]
# Out:
#         name_of_city  state_code state_name  dist_code  population_total  \
# 10            Ajmer            8  RAJASTHAN         21            542580
# 17            Alwar            8  RAJASTHAN          6            315310
# 53         Banswara            8  RAJASTHAN         27            100128
# 54            Baran            8  RAJASTHAN         30            118157
# 68           Beawar            8  RAJASTHAN         21            145809
# 80        Bharatpur            8  RAJASTHAN          7            252109
# 85         Bhilwara            8  RAJASTHAN         24            360009
# 88          Bhiwadi            8  RAJASTHAN          6            104883
# 100         Bikaner            8  RAJASTHAN          3            647804
# 108           Bundi            8  RAJASTHAN         23            102823
# 125    Chittaurgarh            8  RAJASTHAN         28            116409
# 127           Churu            8  RAJASTHAN          4            119846
# ...

# %%
# more than one condition 
df[(df["state_code"]==8) & (df["effective_literacy_rate_total"]<80)]
# Out:
#        name_of_city  state_code state_name  dist_code  population_total  \
# 100        Bikaner            8  RAJASTHAN          3            647804
# 127          Churu            8  RAJASTHAN          4            119846
# 149       Dhaulpur            8  RAJASTHAN          8            126142
# 173  Gangapur City            8  RAJASTHAN         10            119045
# 200    Hanumangarh            8  RAJASTHAN          2            151104
# 209        Hindaun            8  RAJASTHAN          9            105690
# 239     Jhunjhunun            8  RAJASTHAN          5            118966
# 331         Nagaur            8  RAJASTHAN         14            100618
# 360           Pali            8  RAJASTHAN         20            229956
# 434          Sikar            8  RAJASTHAN         13            237579
# 446      Sujangarh            8  RAJASTHAN          4            101528
# 469           Tonk            8  RAJASTHAN         22            165363
#
# ...

# %%
# using query 
df.query("effective_literacy_rate_total>80 and state_code==8")
# Out:
#         name_of_city  state_code state_name  dist_code  population_total  \
# 10            Ajmer            8  RAJASTHAN         21            542580
# 17            Alwar            8  RAJASTHAN          6            315310
# 53         Banswara            8  RAJASTHAN         27            100128
# 54            Baran            8  RAJASTHAN         30            118157
# 68           Beawar            8  RAJASTHAN         21            145809
# 80        Bharatpur            8  RAJASTHAN          7            252109
# 85         Bhilwara            8  RAJASTHAN         24            360009
# 88          Bhiwadi            8  RAJASTHAN          6            104883
# 108           Bundi            8  RAJASTHAN         23            102823
# 125    Chittaurgarh            8  RAJASTHAN         28            116409
# 172      Ganganagar            8  RAJASTHAN          1            224773
# 225          Jaipur            8  RAJASTHAN         12           3073350
# ...
