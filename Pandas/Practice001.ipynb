# %%
# series and dataframe 

import pandas as pd
data = [10,20,30,40,50,60]
series = pd.Series(data)
print(data)
print(series)
# Out:
# [10, 20, 30, 40, 50, 60]
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
data = [10,20,30,40,50,60]
series = pd.Series(data, index=["A","B","C","D","E","F"])
print(series)
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# F    60
# dtype: int64

# %%
# dataframe 
data = {
    "Name":["Ram","Sita"],
    "Age":[32,30]
};
data_frame = pd.DataFrame(data,index=["👉","👉"])
print(data_frame)
# Out:
#    Name  Age
# 👉   Ram   32
# 👉  Sita   30

# %%
# Reading data from file 

read_csv = pd.read_csv("C:/Users/dellj/Desktop/Machine leraning/Pandas/cities_r2.csv")
# use this 👉 "/" insted of "\"
read_csv
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
# head = read above data 
read_csv.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
# reading only 2 rows 
read_csv.head(2)
# Out:
#   name_of_city  state_code   state_name  dist_code  population_total  \
# 0      Abohar            3       PUNJAB          9            145238
# 1    Achalpur           27  MAHARASHTRA          7            112293
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# 1                 6186                   5624  ...             43086
#
#    sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 0        890              848                          79.86
# 1        928              909                          91.99
#
#    effective_literacy_rate_male  effective_literacy_rate_female  \
# 0                         85.49                           73.59
# ...

# %%
# tail = read bottom data
read_csv.tail()
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
#      population_male  population_female  0-6_population_total  \
# 488           111596             115937                 20487
# 489           310400             309716                 55392
# 490            53241              52302                  9754
# 491           115404             101224                 22905
# 492            58717              57997                 11081
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# ...

# %%
# creating a csv file 
read_csv.to_csv("anotherFile.csv",index=False)
another_file = pd.read_csv("anotherFile.csv")
another_file
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
# if index = True, then new column is created
read_csv.to_csv("anotherFile.csv",index=True)
file = pd.read_csv("anotherFile.csv")
file
# new column with unnamed
# Out:
#      Unnamed: 0   name_of_city  state_code      state_name  dist_code  \
# 0             0        Abohar            3          PUNJAB          9
# 1             1      Achalpur           27     MAHARASHTRA          7
# 2             2      Adilabad           28  ANDHRA PRADESH          1
# 3             3     Adityapur           20       JHARKHAND         24
# 4             4         Adoni           28  ANDHRA PRADESH         21
# ..          ...            ...         ...             ...        ...
# 488         488  Vizianagaram           28  ANDHRA PRADESH         12
# 489         489      Warangal           28  ANDHRA PRADESH          9
# 490         490        Wardha           27     MAHARASHTRA          8
# 491         491   Yamunanagar            6         HARYANA          3
# 492         492      Yavatmal           27     MAHARASHTRA         14
#
#      population_total  population_male  population_female  \
# 0              145238            76840              68398
# ...

# %%
# dataframe to csv 
data = {
    "Name":["Radha","Krishan"],
    "Age":[32,35]
}
df = pd.DataFrame(data)
df.to_csv("info.csv",index=False)
new_file = pd.read_csv("info.csv")
new_file
# Out:
#       Name  Age
# A    Radha   32
# B  Krishan   35
#       Name  Age
# 0    Radha   32
# 1  Krishan   35
